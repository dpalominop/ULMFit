# %%
#!pip install tweepy
import tweepy
import csv
import pandas as pd
import numpy as np

# %%
####input your credentials here
consumer_key = 'Xgjb1ZpvGSNxgrS1vZxUpHCeI'
consumer_secret = 'Tsv8e7JyedJTgqwoWCVoYzS4ONXDnBW7AikWdxnc4N7hN5bUUY'
access_token = '1244054822-0inmoNwBrAfVD1wwJkgLKPDaNV9orvxXWLco9nA'
access_token_secret = 'sCBlWkfy4saCMpaEXSyPBPV7J9s9Y3d438TW32TBmFqnv'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
i=0
# geocode="40.42926,-3.6791,50km" spain
# 
for tweet in tweepy.Cursor(api.search, q=".", count=100, lang="es", since="2017-01-01", country_code="PE", geocode="-12.04907,-77.03335,50km").items():
    i+=1
    df_trn = pd.DataFrame({'tweet':np.array([tweet.text]), 'date':np.array([tweet.created_at])}, columns=['date', 'tweet'])
    df_trn.to_csv('tweets-es-pe.csv', header=False, index=False, mode='a')
    if(i%1000 == 0):
        print (i, tweet.created_at, tweet.text)
        if(i == 300000):
            break
# Out:
# 1000 2019-09-17 00:25:02 Con o sin maquillaje, él me ama. 🤗
#
# Psdt.: auspicia la uñas y cabello. 😍 https://t.co/IJkuxiBIr0
# 2000 2019-09-17 00:17:14 RT @elcomercio_peru: Keiko Fujimori podría estar internada una o dos semanas, estima médico https://t.co/EoKbU7u7U6
# 3000 2019-09-17 00:08:57 Jajajajaja que crack https://t.co/vuuByjhjxv
# 4000 2019-09-17 00:00:53 Que crack este chico!!! https://t.co/tPppQXy3GC
# 5000 2019-09-16 23:53:36 RT @ereynaabogado: Panorama presenta pruebas que llevarían a Pedro Cateriano a prisión https://t.co/R7qR4WSDJ6
# 6000 2019-09-16 23:45:51 RT @CarlosOrtegaCTV: Dictadura y opositores oficialistas q no se representan ni ellos mismos instalan diálogo para mantener la narcotiranía…
# 7000 2019-09-16 23:37:25 RT @ClubALoficial: ⚪🔵¡No me quiten esta maldición jamás!⚪🔵
#
# #AlianzaLimaEsElPerú https://t.co/XyDSreSN4c
# 8000 2019-09-16 23:29:35 RT @chatavelit: Mi top ten de asquerosos
#
# 1. @SalvadorHeresi
# 2. @hectorbecerrilr
# 3. #AnabelleBartra
# ...
